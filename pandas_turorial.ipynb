# %%
import pandas as pd

# %%
pd.read_csv("/Users/ajokeogunlolu/Desktop/Data Analytics /CovidDeaths1.csv")
# Out:
#        iso_code continent     location        date  population  total_cases  \
# 0           AFG      Asia  Afghanistan  03/01/2020    41128772          NaN
# 1           AFG      Asia  Afghanistan  04/01/2020    41128772          NaN
# 2           AFG      Asia  Afghanistan  05/01/2020    41128772          NaN
# 3           AFG      Asia  Afghanistan  06/01/2020    41128772          NaN
# 4           AFG      Asia  Afghanistan  07/01/2020    41128772          NaN
# ...         ...       ...          ...         ...         ...          ...
# 351811      ZWE    Africa     Zimbabwe  21/10/2023    16320539     265821.0
# 351812      ZWE    Africa     Zimbabwe  22/10/2023    16320539     265821.0
# 351813      ZWE    Africa     Zimbabwe  23/10/2023    16320539     265821.0
# 351814      ZWE    Africa     Zimbabwe  24/10/2023    16320539     265821.0
# 351815      ZWE    Africa     Zimbabwe  25/10/2023    16320539     265821.0
#
# ...
